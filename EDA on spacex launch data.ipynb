# %% [markdown]
# <div style="background-color: #fc466b; padding: 20px; border-radius: 10px; box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);">
#     <h1 style="text-align: center; font-size: 36px; color: white; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); margin-bottom: 10px;">EDA on SpaceX Launch Data🚀</h1>
#     <p style="text-align: center; font-size: 18px; color: white;">This Notebook give insights based on the SpaceX lauch data Patterns using Exploratory Data Analysis, and helps in understanding the Launch data trends using various features.</p>
# </div>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed

import numpy as np  # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %% [markdown]
# <div style="background-color: #fc466b; padding: 20px; border-radius: 10px; box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);">
#     <h1 style="text-align: center; font-size: 36px; color: white; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); margin-bottom: 40px;">Importing all the Necessary Packages 💻📊</h1>
# </div>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <div style="background-color: #fc466b; padding: 20px; border-radius: 10px; box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);">
#     <h1 style="text-align: center; font-size: 36px; color: white; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); margin-bottom: 40px;">Reading the SpaceX dataset💻📊</h1>
# </div>

# %%
df = pd.read_csv("spacex_launch_data.csv")

# %% [markdown]
# ### *1. Information About A DataFrame*

# %%
df
# Out:
#     Flight Number        Date Time (UTC) Booster Version   Launch Site  \
# 0             1.0  2010-06-04   18:45:00  F9 v1.0  B0003   CCAFS LC-40
# 1             2.0  2010-12-08   15:43:00  F9 v1.0  B0004   CCAFS LC-40
# 2             3.0  2012-05-22    7:44:00  F9 v1.0  B0005   CCAFS LC-40
# 3             4.0  2012-10-08    0:35:00  F9 v1.0  B0006   CCAFS LC-40
# 4             5.0  2013-03-01   15:10:00  F9 v1.0  B0007   CCAFS LC-40
# 5             6.0         NaN   16:00:00  F9 v1.1  B1003   VAFB SLC-4E
# 6             7.0  2013-12-03   22:41:00         F9 v1.1   CCAFS LC-40
# 7             8.0  2014-01-06   22:06:00         F9 v1.1   CCAFS LC-40
# 8             9.0  2014-04-18   19:25:00         F9 v1.1   CCAFS LC-40
# 9            10.0  2014-07-14   15:15:00         F9 v1.1   CCAFS LC-40
# 10           11.0  2014-08-05    8:00:00         F9 v1.1   CCAFS LC-40
# 11           12.0  2014-09-07    5:00:00   F9 v1.1 B1011   CCAFS LC-40
# ...

# %% [markdown]
# **2. Checking for Missing Values and Duplicated Values and fill them.**

# %%
 # filling the Flight Number.....
for i in df.index:
    df.at[i,'Flight Number'] = str(i+1)

# %%
df.isnull().sum()
# Out:
# Flight Number        0
# Date                 3
# Time (UTC)           0
# Booster Version      2
# Launch Site          0
# Payload Mass (kg)    3
# Orbit                0
# Customer             3
# Mission Outcome      3
# Landing Outcome      6
# dtype: int64

# %%
# fill the date coloum.....
df['Date'].fillna(df['Date'].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# Flight Number        0
# Date                 0
# Time (UTC)           0
# Booster Version      2
# Launch Site          0
# Payload Mass (kg)    3
# Orbit                0
# Customer             3
# Mission Outcome      3
# Landing Outcome      6
# dtype: int64

# %%
# fill the Booster Version coloum.....
df['Booster Version'].fillna(df['Booster Version'].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# Flight Number        0
# Date                 0
# Time (UTC)           0
# Booster Version      0
# Launch Site          0
# Payload Mass (kg)    3
# Orbit                0
# Customer             3
# Mission Outcome      3
# Landing Outcome      6
# dtype: int64

# %%
# Transform the data to int because in coloumn weight are in inteager 
# but the datatype is string thats why i convert it to int
digit_list = []
for i in np.array(list(df['Payload Mass (kg)'])) :
    digit = ''
    for k in i:
        if k.isdigit():
            digit += k
    if not len(digit) == 0:   
        digit_list.append(int(digit))
        
# fill the Payload Mass coloum.....
df['Payload Mass (kg)'].fillna(round(np.mean(digit_list)),inplace=True)

# %%
# There are two value name as classified.......convert this to a mass...
for i,j in enumerate(df['Payload Mass (kg)']):
    if not str(j).isdigit():
        df.at[i,'Payload Mass (kg)'] = round(np.mean(digit_list))

# %%
df.isnull().sum()
# Out:
# Flight Number        0
# Date                 0
# Time (UTC)           0
# Booster Version      0
# Launch Site          0
# Payload Mass (kg)    0
# Orbit                0
# Customer             3
# Mission Outcome      3
# Landing Outcome      6
# dtype: int64

# %%
# Fill Customer null value....
df['Customer'].fillna(df['Customer'].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# Flight Number        0
# Date                 0
# Time (UTC)           0
# Booster Version      0
# Launch Site          0
# Payload Mass (kg)    0
# Orbit                0
# Customer             0
# Mission Outcome      3
# Landing Outcome      6
# dtype: int64

# %%
# fill the null value of mission outcome.
df['Mission Outcome'].fillna(df['Mission Outcome'].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# Flight Number        0
# Date                 0
# Time (UTC)           0
# Booster Version      0
# Launch Site          0
# Payload Mass (kg)    0
# Orbit                0
# Customer             0
# Mission Outcome      0
# Landing Outcome      6
# dtype: int64

# %%
# fill the null value of Landing outcome.
df['Landing Outcome'].fillna(df['Landing Outcome'].mode()[0],inplace=True)

# %%
df.isnull().sum()
# Out:
# Flight Number        0
# Date                 0
# Time (UTC)           0
# Booster Version      0
# Launch Site          0
# Payload Mass (kg)    0
# Orbit                0
# Customer             0
# Mission Outcome      0
# Landing Outcome      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Flight Number      57 non-null     object
#  1   Date               57 non-null     object
#  2   Time (UTC)         57 non-null     object
#  3   Booster Version    57 non-null     object
#  4   Launch Site        57 non-null     object
#  5   Payload Mass (kg)  57 non-null     object
#  6   Orbit              57 non-null     object
#  7   Customer           57 non-null     object
#  8   Mission Outcome    57 non-null     object
#  9   Landing Outcome    57 non-null     object
# dtypes: object(10)
# memory usage: 4.6+ KB

# %% [markdown]
# **3. Basic Details Of The Dataset**

# %%
df.describe(include='all')
# Out:
#        Flight Number        Date Time (UTC) Booster Version  Launch Site  \
# count             57          57         57              57           57
# unique            57          54         55              51            4
# top                1  2010-06-04   23:03:00         F9 v1.1  CCAFS LC-40
# freq               1           4          2               7           26
#
#        Payload Mass (kg) Orbit    Customer Mission Outcome Landing Outcome
# count                 57    57          57              57              57
# unique                49     8          29               2              11
# top                 9600   GTO  NASA (CRS)         Success      No attempt
# freq                   5    22          15              54              21

# %%
df.head(5)
# Out:
#   Flight Number        Date Time (UTC) Booster Version  Launch Site  \
# 0             1  2010-06-04   18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1             2  2010-12-08   15:43:00  F9 v1.0  B0004  CCAFS LC-40
# 2             3  2012-05-22    7:44:00  F9 v1.0  B0005  CCAFS LC-40
# 3             4  2012-10-08    0:35:00  F9 v1.0  B0006  CCAFS LC-40
# 4             5  2013-03-01   15:10:00  F9 v1.0  B0007  CCAFS LC-40
#
#   Payload Mass (kg)      Orbit         Customer Mission Outcome  \
# 0              3790        LEO           SpaceX         Success
# 1              3790  LEO (ISS)  NASA (COTS) NRO         Success
# 2               525  LEO (ISS)      NASA (COTS)         Success
# 3               500  LEO (ISS)       NASA (CRS)         Success
# 4               677  LEO (ISS)       NASA (CRS)         Success
#
#          Landing Outcome
# 0  Failure   (parachute)
# 1  Failure   (parachute)
# 2             No attempt
# 3             No attempt
# 4             No attempt

# %% [markdown]
# <div style="background-color: #fc466b; padding: 20px; border-radius: 10px; box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);">
#     <h1 style="text-align: center; font-size: 36px; color: white; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); margin-bottom: 40px;">Data Visualizations 📊📈</h1>
# </div>

# %% [markdown]
# **The Countplots Shows The Orbit, Launch Site, Mission Outcome And Landing Outcome Distributions In The Dataset**

# %%
df.head(5)
# Out:
#   Flight Number        Date Time (UTC) Booster Version  Launch Site  \
# 0             1  2010-06-04   18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1             2  2010-12-08   15:43:00  F9 v1.0  B0004  CCAFS LC-40
# 2             3  2012-05-22    7:44:00  F9 v1.0  B0005  CCAFS LC-40
# 3             4  2012-10-08    0:35:00  F9 v1.0  B0006  CCAFS LC-40
# 4             5  2013-03-01   15:10:00  F9 v1.0  B0007  CCAFS LC-40
#
#   Payload Mass (kg)      Orbit         Customer Mission Outcome  \
# 0              3790        LEO           SpaceX         Success
# 1              3790  LEO (ISS)  NASA (COTS) NRO         Success
# 2               525  LEO (ISS)      NASA (COTS)         Success
# 3               500  LEO (ISS)       NASA (CRS)         Success
# 4               677  LEO (ISS)       NASA (CRS)         Success
#
#          Landing Outcome
# 0  Failure   (parachute)
# 1  Failure   (parachute)
# 2             No attempt
# 3             No attempt
# 4             No attempt

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 16))

sns.countplot(x='Orbit', data=df, ax=axes[0, 0],hue='Orbit')
axes[0, 0].set_title('Orbital Distribution')
axes[0, 0].tick_params(axis='x', rotation=90)

sns.countplot(x='Launch Site', data=df, ax=axes[0, 1],hue='Launch Site')
axes[0, 1].set_title('Launch Site Distribution')
axes[0, 1].tick_params(axis='x', rotation=90)

sns.countplot(x='Mission Outcome', data=df, ax=axes[1, 0],hue='Mission Outcome')
axes[1, 0].set_title('Mission Outcome Distribution')
axes[1, 0].tick_params(axis='x', rotation=90)

sns.countplot(x='Landing Outcome', data=df, ax=axes[1, 1],hue='Landing Outcome')
axes[1, 1].set_title('Landing Outcome Distribution')
axes[1, 1].tick_params(axis='x', rotation=90)

plt.tight_layout()
plt.show()

# %%
df.head(2)
# Out:
#   Flight Number        Date Time (UTC) Booster Version  Launch Site  \
# 0             1  2010-06-04   18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1             2  2010-12-08   15:43:00  F9 v1.0  B0004  CCAFS LC-40
#
#   Payload Mass (kg)      Orbit         Customer Mission Outcome  \
# 0              3790        LEO           SpaceX         Success
# 1              3790  LEO (ISS)  NASA (COTS) NRO         Success
#
#          Landing Outcome
# 0  Failure   (parachute)
# 1  Failure   (parachute)

# %% [markdown]
# **Scatter Plot Between Time With Landing Outcome**

# %%
plt.figure(figsize=(20, 15))
sns.scatterplot(x='Landing Outcome', y='Time (UTC)', data=df, hue='Orbit', style='Mission Outcome', s=180)
plt.title('Relationship between Time with Landing Outcome by Orbit and Mission Outcome')
plt.xlabel('Landing Outcome')
plt.ylabel('Time')
plt.grid(True)
plt.legend(title='Orbit / Mission Outcome', loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Scatter Plot Between Payload Mass & Mission Outcome & Landing Orbit**

# %%
df.head(2)
# Out:
#   Flight Number        Date Time (UTC) Booster Version  Launch Site  \
# 0             1  2010-06-04   18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1             2  2010-12-08   15:43:00  F9 v1.0  B0004  CCAFS LC-40
#
#   Payload Mass (kg)      Orbit         Customer Mission Outcome  \
# 0              3790        LEO           SpaceX         Success
# 1              3790  LEO (ISS)  NASA (COTS) NRO         Success
#
#          Landing Outcome
# 0  Failure   (parachute)
# 1  Failure   (parachute)

# %%
fig, axes = plt.subplots(1, 2,figsize=(16, 4))
sns.scatterplot(x='Mission Outcome',y='Payload Mass (kg)',data=df,hue='Orbit',ax=axes[0])
axes[0].legend(fontsize = 6,loc='upper center')
axes[0].grid()

sns.boxplot(x='Mission Outcome',y='Payload Mass (kg)',data=df,hue='Orbit',ax=axes[1])
axes[1].legend(fontsize = 6,loc='lower right')

plt.show()

# %% [markdown]
# #### Bosster Version vs Payload Carry

# %%
df.head(2)
# Out:
#   Flight Number        Date Time (UTC) Booster Version  Launch Site  \
# 0             1  2010-06-04   18:45:00  F9 v1.0  B0003  CCAFS LC-40
# 1             2  2010-12-08   15:43:00  F9 v1.0  B0004  CCAFS LC-40
#
#   Payload Mass (kg)      Orbit         Customer Mission Outcome  \
# 0              3790        LEO           SpaceX         Success
# 1              3790  LEO (ISS)  NASA (COTS) NRO         Success
#
#          Landing Outcome
# 0  Failure   (parachute)
# 1  Failure   (parachute)

# %%
plt.figure(figsize=(12,6))
a = list(df['Booster Version']) 
b = [int(i) for i in list(df['Payload Mass (kg)'])]
plt.xlabel('Booster Version')
plt.ylabel('Payload Mass (kg)')
plt.title('Booster vs Payload')
plt.xticks([i for i in range(len(a))],a,rotation = 90)
plt.bar([i for i in range(len(a))],b,color='g')
plt.show()

# %% [markdown]
# **The Countplot Shows How Many Launches Are Succeed In Different Orbit**

# %%
plt.figure(figsize=(6, 8))
sns.countplot(x='Orbit', hue='Mission Outcome', data=df)
plt.title('Orbit Vs Successful Launch')
plt.xlabel('Orbit')
plt.ylabel('Successful Launch')
plt.xticks(rotation=90)
plt.legend(title='Mission Outcome')
plt.tight_layout()
plt.show()

# %% [markdown]
# **The Countplot Shows How Many Launches Are Succeed In Different Launch Site**

# %%
plt.figure(figsize=(14, 7))
sns.countplot(x='Launch Site', hue='Mission Outcome', data=data)
plt.title('Launch Site and Mission Outcome')
plt.xlabel('Launch Site')
plt.ylabel('Mission Outcome')
plt.xticks(rotation=45)
plt.legend(title='Result', loc='upper right')
plt.tight_layout()
plt.show()

# %% [markdown]
# <div style="background-color: #fc466b; padding: 20px; border-radius: 10px; box-shadow: 0 4px 6px rgba(0, 0, 0, 0.1);">
#     <h1 style="text-align: center; font-size: 36px; color: white; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3); margin-bottom: 40px;">Thanks for Being till here! 😊</h1>
